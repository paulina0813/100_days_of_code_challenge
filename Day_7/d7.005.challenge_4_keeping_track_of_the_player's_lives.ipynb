# %% [markdown]
# # Challenge 4 - Keeping Track of the Player's Lives
#
# The fourth part of the challenge consists of keeping track of the player's lives:
# 1. Track the amount of lives left
# 2. If the user's guess is not in the word, then they lose a life
# 3. Print the ASCII art

# %%
#Step 4

import random

stages = ['''
  +---+
  |   |
  O   |
 /|\  |
 / \  |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
 /    |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|   |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
  |   |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
      |
      |
      |
=========
''', '''
  +---+
  |   |
      |
      |
      |
      |
=========
''']

end_of_game = False
word_list = ["ardvark", "baboon", "camel"]
chosen_word = random.choice(word_list)
word_length = len(chosen_word)

#TODO-1: - Create a variable called 'lives' to keep track of the number of lives left. 
#Set 'lives' to equal 6.
lives = 6
#Testing code
print(f'Pssst, the solution is {chosen_word}.')

#Create blanks
display = []
for _ in range(word_length):
    display += "_"

while not end_of_game:
    guess = input("Guess a letter: ").lower()

    #Check guessed letter
    for position in range(word_length):
        letter = chosen_word[position]
        # print(f"Current position: {position}\n Current letter: {letter}\n Guessed letter: {guess}")
        if letter == guess:
            display[position] = letter
        
    #TODO-2: - If guess is not a letter in the chosen_word,
    #Then reduce 'lives' by 1. 
    #If lives goes down to 0 then the game should stop and it should print "You lose."
    if guess not in chosen_word:
        lives -= 1
        print("Lives left:", lives)
        if lives == 0:
            print("You lose.")
            end_of_game = True
    #Join all the elements in the list and turn it into a String.
    print(f"{' '.join(display)}")

    #Check if user has got all letters.
    if "_" not in display:
        end_of_game = True
        print("You win.")

    #TODO-3: - print the ASCII art from 'stages' that corresponds to the current number of 'lives' the user has remaining.
    print(stages[lives])
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# <>:21: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# <>:21: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/24/3_yglng17vd67xnd6d655y3h0000gp/T/ipykernel_93617/1579356255.py:5: SyntaxWarning: invalid escape sequence '\ '
#   stages = ['''
# /var/folders/24/3_yglng17vd67xnd6d655y3h0000gp/T/ipykernel_93617/1579356255.py:13: SyntaxWarning: invalid escape sequence '\ '
#   ''', '''
# /var/folders/24/3_yglng17vd67xnd6d655y3h0000gp/T/ipykernel_93617/1579356255.py:21: SyntaxWarning: invalid escape sequence '\ '
#   ''', '''
# Pssst, the solution is camel.
# _ a _ _ _
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# ...
#
# _ a m _ _
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# ...
#
# 5
# _ a m _ _
#
#   +---+
#   |   |
#   O   |
#       |
#       |
# ...
