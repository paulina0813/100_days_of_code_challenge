# %% [markdown]
# # Flow Chart Programming
#
# First, we need to draw out a flow chart to represent the logic of our game (hangman).
#
# ![Screenshot 2024-07-14 at 20.34.35.png](<attachment:Screenshot 2024-07-14 at 20.34.35.png>)
