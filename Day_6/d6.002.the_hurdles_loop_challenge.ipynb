# %% [markdown]
# # Hurdle's Challenge
#
# - Head over to this link: https://reeborg.ca/reeborg.html?lang=en&mode=python&menu=worlds%2Fmenus%2Freeborg_intro_en.json&name=Hurdle%201&url=worlds%2Ftutorial_en%2Fhurdle1.json
#
# - You have to get the robot to jump over the hurdles ot make it all the way to the end of the course using the available functions and creating new ones when needed

# %% [raw]
# def turn_right():
#     turn_left()
#     turn_left()
#     turn_left()
#
# def jump():
#     move()
#     turn_left()
#     move()
#     turn_right()
#     move()
#     turn_right()
#     move()
#     turn_left()
#
# for i in range(1,7):
#     jump()
